# %%
# %%bash
# echo "Instalando dependência"
# pip install google-generativeai python-dotenv pandas streamlit
# echo "terminado"
# Out:
# Instalando dependência
# ...
# terminado

# %%
import streamlit as st
import google.generativeai as genai
import pandas as pd
import json
